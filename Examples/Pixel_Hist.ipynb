# %%
import numpy as np

# for plotting
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
On18c6_11 = np.load("HistData/18c6On_11.npy")
On18c6_12 = np.load("HistData/18c6On_12.npy")
On18c6_13 = np.load("HistData/18c6On_13.npy")

On18c6_21 = np.load("HistData/18c6On_21.npy")
On18c6_22 = np.load("HistData/18c6On_22.npy")
On18c6_23 = np.load("HistData/18c6On_23.npy")


Off18c6_11 = np.load("HistData/18c6Off_11.npy")
Off18c6_12 = np.load("HistData/18c6Off_12.npy")
Off18c6_13 = np.load("HistData/18c6Off_13.npy")

Off18c6_21 = np.load("HistData/18c6Off_21.npy")
Off18c6_22 = np.load("HistData/18c6Off_22.npy")
Off18c6_23 = np.load("HistData/18c6Off_23.npy")


BapOn18c6_11 = np.load("HistData/Bap18c6On_11.npy")
BapOn18c6_12 = np.load("HistData/Bap18c6On_12.npy")
BapOn18c6_13 = np.load("HistData/Bap18c6On_13.npy")

BapOn18c6_21 = np.load("HistData/Bap18c6On_21.npy")
BapOn18c6_22 = np.load("HistData/Bap18c6On_22.npy")
#BapOn18c6_23 = np.load("HistData/Bap18c6On_23.npy")


BapOff18c6_11 = np.load("HistData/Bap18c6Off_11.npy")
BapOff18c6_12 = np.load("HistData/Bap18c6Off_12.npy")
BapOff18c6_13 = np.load("HistData/Bap18c6Off_13.npy")

BapOff18c6_21 = np.load("HistData/Bap18c6Off_21.npy")
BapOff18c6_22 = np.load("HistData/Bap18c6Off_22.npy")
BapOff18c6_23 = np.load("HistData/Bap18c6Off_23.npy")

# %%
plt.figure(figsize=(7,7))
xval = np.arange(0,len(On18c6_11),1)
plt.plot(xval,On18c6_11,label='On18c6_11',lw=3,alpha=0.8)
plt.plot(xval,On18c6_12,label='On18c6_12',lw=3,alpha=0.8)
plt.plot(xval,On18c6_13,label='On18c6_13',lw=3,alpha=0.8)

plt.plot(xval,On18c6_21,label='On18c6_21',lw=3,alpha=0.8,linestyle='--')
plt.plot(xval,On18c6_22,label='On18c6_22',lw=3,alpha=0.8,linestyle='--')
plt.plot(xval,On18c6_23,label='On18c6_23',lw=3,alpha=0.8,linestyle='--')


plt.legend(loc='upper right',fontsize=16,bbox_to_anchor=(1.2, 1.05))
plt.xlabel("Number bin", fontsize=15)
plt.ylabel("Counts", fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid()
#plt.xlim(10,310)
plt.semilogy()
plt.show()

# %%
plt.figure(figsize=(7,7))
xval = np.arange(0,len(Off18c6_11),1)
plt.plot(xval,Off18c6_11,label='Off18c6_11',lw=3,alpha=0.8)
plt.plot(xval,Off18c6_12,label='Off18c6_12',lw=3,alpha=0.8)
plt.plot(xval,Off18c6_13,label='Off18c6_13',lw=3,alpha=0.8)

plt.plot(xval,Off18c6_21,label='Off18c6_21',lw=3,alpha=0.8,linestyle='--')
plt.plot(xval,Off18c6_22,label='Off18c6_22',lw=3,alpha=0.8,linestyle='--')
plt.plot(xval,Off18c6_23,label='Off18c6_23',lw=3,alpha=0.8,linestyle='--')


plt.legend(loc='upper right',fontsize=16,bbox_to_anchor=(1.2, 1.05))
plt.xlabel("Number bin", fontsize=15)
plt.ylabel("Counts", fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid()
#plt.xlim(10,310)
plt.semilogy()
plt.show()

# %%
plt.figure(figsize=(7,7))
xval = np.arange(0,len(On18c6_11),1)
plt.plot(xval,BapOn18c6_11,label='BapOn18c6_11',lw=3,alpha=0.8)
plt.plot(xval,BapOn18c6_12,label='BapOn18c6_12',lw=3,alpha=0.8)
plt.plot(xval,BapOn18c6_13,label='BapOn18c6_13',lw=3,alpha=0.8)

plt.plot(xval,BapOn18c6_21,label='BapOn18c6_21',lw=3,alpha=0.8,linestyle='--')
plt.plot(xval,BapOn18c6_22,label='BapOn18c6_22',lw=3,alpha=0.8,linestyle='--')
#plt.plot(xval,BapOn18c6_23,label='BapOn18c6_23',lw=3,alpha=0.8,linestyle='--')


plt.legend(loc='upper right',fontsize=16,bbox_to_anchor=(1.2, 1.05))
plt.xlabel("Number bin", fontsize=15)
plt.ylabel("Counts", fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid()
#plt.xlim(10,310)
plt.semilogy()
plt.show()

# %%
plt.figure(figsize=(7,7))
xval = np.arange(0,len(Off18c6_11),1)
plt.plot(xval,BapOff18c6_11,label='BapOff18c6_11',lw=3,alpha=0.8)
plt.plot(xval,BapOff18c6_12,label='BapOff18c6_12',lw=3,alpha=0.8)
plt.plot(xval,BapOff18c6_13,label='BapOff18c6_13',lw=3,alpha=0.8)

plt.plot(xval,BapOff18c6_21,label='BapOff18c6_21',lw=3,alpha=0.8,linestyle='--')
plt.plot(xval,BapOff18c6_22,label='BapOff18c6_22',lw=3,alpha=0.8,linestyle='--')
plt.plot(xval,BapOff18c6_23,label='BapOff18c6_23',lw=3,alpha=0.8,linestyle='--')


plt.legend(loc='upper right',fontsize=16,bbox_to_anchor=(1.2, 1.05))
plt.xlabel("Number bin", fontsize=15)
plt.ylabel("Counts", fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid()
#plt.xlim(10,310)
plt.semilogy()
plt.show()

# %%
ON18c6  = np.array([On18c6_11,On18c6_12,On18c6_13,On18c6_21,On18c6_22,On18c6_23])
OFF18c6 = np.array([Off18c6_11,Off18c6_12,Off18c6_13,Off18c6_21,Off18c6_22,Off18c6_23])

# %%
BAPON18c6  = np.array([BapOn18c6_11,BapOn18c6_12,BapOn18c6_13,BapOn18c6_21,BapOn18c6_22])
BAPOFF18c6 = np.array([BapOff18c6_11,BapOff18c6_12,BapOff18c6_13,BapOff18c6_21,BapOff18c6_22,BapOff18c6_23])

# %%
plt.figure(figsize=(7,7))
#xval = np.arange(0,len(poly11),1)


plt.plot(xval, np.mean(OFF18c6,axis=0), color='k',label="OFF18c6",lw=3)
MX = np.max(OFF18c6,axis=0)
MN = np.min(OFF18c6,axis=0)
plt.fill_between(xval, MN,MX,color='k',alpha=0.3)

plt.plot(xval, np.mean(ON18c6,axis=0), color='b',label="ON18c6",lw=3)
MX = np.max(ON18c6,axis=0)
MN = np.min(ON18c6,axis=0)
plt.fill_between(xval, MN,MX,color='b',alpha=0.3)



plt.plot(xval, np.mean(BAPOFF18c6,axis=0), color='r',label="BapOFF18c6",lw=3)
MX = np.max(BAPOFF18c6,axis=0)
MN = np.min(BAPOFF18c6,axis=0)
plt.fill_between(xval, MN,MX,color='r',alpha=0.3)

plt.plot(xval, np.mean(BAPON18c6,axis=0), color='g',label="BapON18c6",lw=3)
MX = np.max(BAPON18c6,axis=0)
MN = np.min(BAPON18c6,axis=0)
plt.fill_between(xval, MN,MX,color='g',alpha=0.3)


plt.legend(loc='upper right',fontsize=16)
plt.xlabel("Number bin", fontsize=15)
plt.ylabel("Counts", fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid()
#plt.xlim(0,304)
#plt.ylim(1e-7,1e6)

plt.semilogy()
plt.show()

# %%
plt.figure(figsize=(7,7))
#xval = np.arange(0,len(poly11),1)


plt.plot(xval, np.mean(OFF18c6,axis=0), color='k',label="OFF18c6",lw=3)
MX = np.max(OFF18c6,axis=0)
MN = np.min(OFF18c6,axis=0)
plt.fill_between(xval, MN,MX,color='k',alpha=0.3)

plt.plot(xval, np.mean(ON18c6,axis=0), color='b',label="ON18c6",lw=3)
MX = np.max(ON18c6,axis=0)
MN = np.min(ON18c6,axis=0)
plt.fill_between(xval, MN,MX,color='b',alpha=0.3)



plt.plot(xval, np.mean(BAPOFF18c6,axis=0), color='r',label="BapOFF18c6",lw=3)
MX = np.max(BAPOFF18c6,axis=0)
MN = np.min(BAPOFF18c6,axis=0)
plt.fill_between(xval, MN,MX,color='r',alpha=0.3)

plt.plot(xval, np.mean(BAPON18c6,axis=0), color='g',label="BapON18c6",lw=3)
MX = np.max(BAPON18c6,axis=0)
MN = np.min(BAPON18c6,axis=0)
plt.fill_between(xval, MN,MX,color='g',alpha=0.3)


plt.legend(loc='upper right',fontsize=16)
plt.xlabel("Number bin", fontsize=15)
plt.ylabel("Counts", fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid()
plt.xlim(50,504)
#plt.ylim(1e-7,1e6)

plt.semilogy()
plt.show()

# %%
plt.figure(figsize=(7,7))
#xval = np.arange(0,len(poly11),1)


plt.plot(xval, np.mean(OFF18c6,axis=0), color='k',label="OFF18c6",lw=3)

plt.plot(xval, np.mean(ON18c6,axis=0), color='b',label="ON18c6",lw=3)

plt.plot(xval, np.mean(BAPOFF18c6,axis=0), color='r',label="BapOFF18c6",lw=3)

plt.plot(xval, np.mean(BAPON18c6,axis=0), color='g',label="BapON18c6",lw=3)



plt.legend(loc='upper right',fontsize=16)
plt.xlabel("Number bin", fontsize=15)
plt.ylabel("Counts", fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid()
#plt.xlim(0,304)
#plt.ylim(1e-7,1e6)

plt.semilogy()
plt.show()

# %%
plt.figure(figsize=(7,7))
xval = np.arange(0,len(poly11),1)


plt.plot(xval, np.mean(POLY,axis=0), color='b',label="poly",lw=3)
MX = np.max(POLY,axis=0)
MN = np.min(POLY,axis=0)
plt.fill_between(xval, MN,MX,color='b',alpha=0.3)

plt.plot(xval, np.mean(COPOLY,axis=0), color='r',label="Copoly",lw=3)
MX = np.max(COPOLY,axis=0)
MN = np.min(COPOLY,axis=0)
plt.fill_between(xval, MN,MX,color='r',alpha=0.3)


plt.plot(xval, np.mean(COPOLYBA,axis=0), color='k',label="Copoly+Ba",lw=3)
MX = np.max(COPOLYBA,axis=0)
MN = np.min(COPOLYBA,axis=0)
plt.fill_between(xval, MN,MX,color='k',alpha=0.3)

plt.plot(xval, np.mean(BACOPOLY,axis=0), color='g',label="baCopoly",lw=3)
MX = np.max(BACOPOLY,axis=0)
MN = np.min(BACOPOLY,axis=0)
plt.fill_between(xval, MN,MX,color='g',alpha=0.3)


plt.legend(loc='upper right',fontsize=16)
plt.xlabel("Number of Photo Electrons", fontsize=15)
plt.ylabel("Counts", fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid()
plt.xlim(100,304)
#plt.ylim(1e-7,1e6)

plt.semilogy()
plt.show()

# %%
min(low)

# %%
np.std(COPOLYBA,axis=0)

# %%
from glob import glob

# %%
datafiles = glob("HistData/*")

# %%
datafiles[0].split("HistData/")[1].split(".npy")[0]
# Out:
# 'Bap18c6Off_11'

# %%
dat = {}
for d in datafiles:
    name = d.split("HistData/")[1].split(".npy")[0]
    dat[name] = np.load(d)

# %%
KEYS = []
for key in dat.keys():
    KEYS.append(key)
KEYS
# Out:
# ['Bap18c6Off_11',
#  'Bap18c6Off_13',
#  'Bap18c6Off_12',
#  '18c6Off_21',
#  '18c6On_23',
#  '18c6On_22',
#  'Bap18c6On_21',
#  'Bap18c6On_23',
#  '18c6Off_22',
#  '18c6On_21',
#  '18c6Off_23',
#  'Bap18c6On_22',
#  'Bap18c6On_13',
#  '18c6Off_12',
#  '18c6On_11',
#  '18c6Off_13',
#  'Bap18c6On_12',
#  '18c6Off_11',
#  '18c6On_13',
#  '18c6On_12',
#  'Bap18c6On_11',
#  'Bap18c6Off_23',
#  'Bap18c6Off_22',
#  'Bap18c6Off_21']

# %%
plt.figure(figsize=(7,7))
xval = np.arange(0,len(dat['18c6On_11']),1)

plt.plot(xval,dat['18c6On_11'],label='On18c6_11',lw=3,alpha=0.8)
plt.plot(xval,dat['18c6On_12'],label='On18c6_12',lw=3,alpha=0.8)
plt.plot(xval,dat['18c6On_13'],label='On18c6_13',lw=3,alpha=0.8)

plt.plot(xval,dat['18c6On_21'],label='On18c6_21',lw=3,alpha=0.8,linestyle='--')
plt.plot(xval,dat['18c6On_22'],label='On18c6_22',lw=3,alpha=0.8,linestyle='--')
plt.plot(xval,dat['18c6On_23'],label='On18c6_23',lw=3,alpha=0.8,linestyle='--')


plt.legend(loc='upper right',fontsize=16,bbox_to_anchor=(1.2, 1.05))
plt.xlabel("Number bin", fontsize=15)
plt.ylabel("Counts", fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid()
#plt.xlim(10,310)
plt.semilogy()
plt.show()

# %%
plt.figure(figsize=(7,7))
xval = np.arange(0,len(dat['18c6Off_11']),1)

plt.plot(xval,dat['18c6Off_11'],label='Off18c6_11',lw=3,alpha=0.8)
plt.plot(xval,dat['18c6Off_12'],label='Off18c6_12',lw=3,alpha=0.8)
plt.plot(xval,dat['18c6Off_13'],label='Off18c6_13',lw=3,alpha=0.8)

plt.plot(xval,dat['18c6Off_21'],label='Off18c6_21',lw=3,alpha=0.8,linestyle='--')
plt.plot(xval,dat['18c6Off_22'],label='Off18c6_22',lw=3,alpha=0.8,linestyle='--')
plt.plot(xval,dat['18c6Off_23'],label='Off18c6_23',lw=3,alpha=0.8,linestyle='--')


plt.legend(loc='upper right',fontsize=16,bbox_to_anchor=(1.2, 1.05))
plt.xlabel("Number bin", fontsize=15)
plt.ylabel("Counts", fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid()
#plt.xlim(10,310)
plt.semilogy()
plt.show()
